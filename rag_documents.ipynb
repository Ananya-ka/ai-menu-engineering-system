# %%
import pandas as pd

df = pd.read_csv("data/processed/menu_metrics.csv")
df.head()
# Out:
#    Unnamed: 0  item_id          item_name    category  price  \
# 0           0      101       Garlic Knots  Appetizers   8.99
# 1           1      102       Loaded Fries  Appetizers  12.50
# 2           2      103         Bruschetta  Appetizers  10.50
# 3           3      104  Stuffed Mushrooms  Appetizers  11.00
# 4           4      105      Buffalo Wings  Appetizers  13.50
#
#    prep_time_minutes  units_sold_last_month  profit_margin_percent   COGS  \
# 0                  5                    159                     46  10.87
# 1                  8                    490                     38   4.49
# 2                  6                     46                     43  12.32
# 3                  7                     62                     64   6.36
# 4                  9                    361                     75  15.86
#
#    revenue     profit popularity_tier profitability_tier menu_class
# 0  1429.41   657.5286             Low                Low    Low-Low
# 1  6125.00  2327.5000            High               High  High-High
# 2   483.00   207.6900             Low                Low    Low-Low
# 3   682.00   436.4800             Low                Low    Low-Low
# 4  4873.50  3655.1250            High               High  High-High

# %%
from langchain_core.documents import Document

documents = []

for _, row in df.iterrows():
    content = (
        f"Menu item '{row['item_name']}' is in category '{row['category']}'. "
        f"It is priced at {row['price']}. "
        f"It sold {row['units_sold_last_month']} units last month. "
        f"Profit margin is {row['profit_margin_percent']}%. "
        f"Total profit generated was {round(row['profit'], 2)}. "
        f"Average preparation time is {row['prep_time_minutes']} minutes. "
        f"Menu classification is {row['menu_class']}."
    )

    metadata = {
        "item_id": row["item_id"],
        "item_name": row["item_name"],
        "category": row["category"],
        "price": row["price"],
        "units_sold": row["units_sold_last_month"],
        "profit_margin": row["profit_margin_percent"],
        "profit": round(row["profit"], 2),
        "prep_time": row["prep_time_minutes"],
        "menu_class": row["menu_class"],
        "source": "pos_sql"
    }

    documents.append(
        Document(page_content=content, metadata=metadata)
    )

len(documents)
# Out:
# 53

# %%
documents[0].page_content
documents[0].metadata
# Out:
# {'item_id': 101,
#  'item_name': 'Garlic Knots',
#  'category': 'Appetizers',
#  'price': 8.99,
#  'units_sold': 159,
#  'profit_margin': 46,
#  'profit': 657.53,
#  'prep_time': 5,
#  'menu_class': 'Low-Low',
#  'source': 'pos_sql'}

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_documents(
    documents,
    embedding_model
)
# Out:
# /var/folders/s1/s94qmf4129q34gqmyptfrk4w0000gn/T/ipykernel_33204/2834206051.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(

# %%
vectorstore.save_local("data/processed/faiss_index")

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

docs = retriever.invoke("Which menu items are most profitable?")

for d in docs:
    print("-", d.metadata["item_name"], d.metadata["profit"])
# Out:
# - Mac and Cheese 432.53
# - Nacho Platter 4248.4
# - Bruschetta 207.69
